# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/Users/sebastiaanscholten/Documents/speech2image-master/experiments/TTS/TTSproject-82632c0ccf87.json"
import sys
sys.path.append("../")
from helper import tokenize,dicttodf,MP3toWAV

# %%
def makeMP3fromList(list):
    for word in list:
        synthesize_text(word)
        
def makeMP3fromDict(dict):
    for word in dict:
        synthesize_text(word)

def synthesize_text(text):
    """Synthesizes speech from the input string of text."""
    from google.cloud import texttospeech
    client = texttospeech.TextToSpeechClient()

    input_text = texttospeech.types.SynthesisInput(text=text)

    # Note: the voice can also be specified by name.
    # Names of voices can be retrieved with client.list_voices().
    voice = texttospeech.types.VoiceSelectionParams(
        language_code='en-US',
        name='en-US-Wavenet-D',
        ssml_gender=texttospeech.enums.SsmlVoiceGender.MALE)

    audio_config = texttospeech.types.AudioConfig(
        audio_encoding=texttospeech.enums.AudioEncoding.MP3)

    response = client.synthesize_speech(input_text, voice, audio_config)

    # The response's audio_content is binary.
    with open(f'Flickr8kWordsMP3/{text}.mp3', 'wb') as out:
        out.write(response.audio_content)
        print(f'Audio content written to file "{text}.mp3"')

# %%
path = "../data/Flickr8k_text/Flickr8k.token.txt"
wordlist, worddictionary = tokenize(path)

#this is for generating the MP3 files

# dictdf = dicttodf(worddictionary)
# newloop = list(dictdf.iloc[7680:,0])
# makeMP3fromList(newloop)

# %%
directory = "Flickr8kWordsMP3/"

#this is for generating the .wav files
for filename in os.listdir(directory):
    if filename.endswith(".mp3"):
        MP3toWAV(filename,fromdirectory="Flickr8kWordsMP3/",todirectory="Flickr8kWordsWAV/")
        print(".wav created for:", filename)
        continue
    else:
        continue
# Out:
# .wav created for: uncrowded.mp3
# .wav created for: somersault.mp3
# .wav created for: cigarettes.mp3
# .wav created for: excavating.mp3
# .wav created for: bodyboard.mp3
# .wav created for: ages.mp3
# .wav created for: shrubs.mp3
# .wav created for: peek.mp3
# .wav created for: gotten.mp3
# .wav created for: beaten.mp3
# .wav created for: noticable.mp3
# .wav created for: wedding.mp3
# .wav created for: lunch.mp3
# .wav created for: headlamp.mp3
# .wav created for: sparring.mp3
# .wav created for: aged.mp3
# .wav created for: tartan.mp3
# .wav created for: leaf.mp3
# .wav created for: ponytail.mp3
# .wav created for: docking.mp3
# .wav created for: specialized.mp3
# .wav created for: spokesmodels.mp3
# .wav created for: beat.mp3
# .wav created for: tanning.mp3
# .wav created for: competitors.mp3
# .wav created for: toilet.mp3
# .wav created for: coffin.mp3
# .wav created for: kneeling.mp3
# .wav created for: strips.mp3
# .wav created for: fireball.mp3
# ...
