# %%
import sys
sys.path.append("../")
import nltk
import pandas as pd
import numpy as np
from helper import tokenize, dicttodf
import json

# %%
path = "../data/Flickr8k_text/Flickr8k.token.txt"
wordlist, worddictionary = tokenize("../data/Flickr8k_text/Flickr8k.token.txt")
worddf = dicttodf(worddictionary)

# %%
path2 = "/Users/sebastiaanscholten/Documents/speech2image-master/experiments/data/imagenet_class_index.json"

with open(path2,"r") as json_file:
    data = json.load(json_file)

# %%
wordlist1 = list(worddf["words"])
wordlist2 = []
for words in data.values():
    wordlist2.append(words[1])

# %%
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3 
intersect = intersection(wordlist1,wordlist2)

# %%
worddf = worddf[worddf["words"].isin(intersect)]

# %%
#100 words which are both in imagenet as in 
pd.set_option('display.max_rows', 500)
worddf[0:100]
# Out:
#            words  counts
# 85        orange     745
# 151   basketball     396
# 156        swing     382
# 188     baseball     298
# 195   sunglasses     277
# 212         suit     249
# 257        cliff     195
# 272     fountain     181
# 299     backpack     159
# 302         pole     157
# 379       jersey     114
# 412          ski     103
# 443         dock      93
# 473     umbrella      86
# 478   restaurant      85
# 492         mask      81
# 506   sweatshirt      78
# 511         tank      77
# 545        canoe      72
# 564   microphone      67
# 581       bikini      66
# 589        stage      65
# 604       bucket      62
# 621   volleyball      60
# 661          cup      55
# 678       racket      52
# 705        racer      50
# 761      cricket      44
# 764      balloon      44
# 810       paddle      40
# 837          ear      39
# 841          fly      38
# 850          hay      38
# 855     unicycle      38
# 860       bubble      37
# 861        purse      37
# 877       muzzle      36
# 884        chain      36
# 890        plate      36
# 892         kite      36
# 898         jeep      35
# 922         pier      34
# 925    parachute      34
# 945     necklace      32
# 964       violin      31
# 989       collie      30
# 1022      screen      28
# 1040       plane      28
# 1046       chest      28
# 1056        drum      27
# 1096        jean      26
# 1112        corn      25
# 1117        puck      25
# 1168      valley      23
# 1173    tricycle      23
# 1193       groom      22
# 1209      barrel      22
# 1228       tiger      21
# 1242         bow      21
# 1261       patio      21
# 1277      church      20
# 1279      pirate      20
# 1285       apron      20
# 1322     pitcher      19
# 1362       boxer      18
# 1385        desk      18
# 1470      pillow      16
# 1503     whistle      15
# 1512      beagle      15
# 1517       crane      15
# 1520      shovel      15
# 1557  binoculars      15
# 1566     bathtub      15
# 1574      tripod      14
# 1645  snowmobile      13
# 1650         tub      13
# 1653         wig      13
# 1662        barn      13
# 1730        pick      12
# 1731      laptop      12
# 1759       flute      12
# 1770         bee      12
# 1837      cannon      11
# 1856       stove      10
# 1859       pizza      10
# 1903       mouse      10
# 1905     library      10
# 1931   accordion      10
# 1934   ambulance      10
# 1935         pot      10
# 1937     tractor      10
# 1989         pug       9
# 2009        gown       9
# 2027  television       9
# 2102       broom       9
# 2206    seashore       8
# 2244       teddy       8
# 2305      castle       7
# 2323        tray       7
# 2350    lipstick       7
