# %%
#!/usr/bin/env python
from __future__ import print_function

import os
import tables
import argparse
import sys

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid


import numpy as np
import pandas as pd
import seaborn as sn
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import librosa.display
import h5py

# %%
hdf = h5py.File('data/flickr_features-18jan.h5',mode="r")

#hdf.get('flickr_1000268201_693b08cb0e')
testgroup = hdf.get('flickr_1000268201_693b08cb0e')
testgroup = testgroup.get("mfcc")
testgroup = testgroup.get('flickr_1000268201_693b08cb0e_0')

mfcc = np.array(testgroup)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-89f3e48c07d5> in <module>
# ----> 1 hdf = h5py.File('data/flickr_features-18jan.h5',mode="r")
#       2
#       3 #hdf.get('flickr_1000268201_693b08cb0e')
#       4 testgroup = hdf.get('flickr_1000268201_693b08cb0e')
#       5 testgroup = testgroup.get("mfcc")
#
# ~/opt/anaconda3/envs/paperreproduction/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
#     396             if swmr_support:
#
# ~/opt/anaconda3/envs/paperreproduction/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     168         if swmr and swmr_support:
#     169             flags |= h5f.ACC_SWMR_READ
# --> 170         fid = h5f.open(name, flags, fapl=fapl)
#     171     elif mode == 'r+':
#     172         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (truncated file: eof = 2508193792, sblock->base_addr = 0, stored_eof = 3996452016)

# %%
mfcc = mfcc.transpose()
x = librosa.display.specshow(mfcc,x_axis='time');
